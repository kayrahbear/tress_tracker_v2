# %%
import pandas as pd

# %%
data = pd.read_csv("scrapingwigs/scrapingwigs/spiders/each_wig.csv")

# %%
data.head()
# Out:
#     brand                                             colors  \
# 0  Noriko  [('Iced Mocha-R +$12.75', 'https://cdn.shopify...
# 1  Noriko  [('Sugar Cane-R', 'https://cdn.shopify.com/s/f...
# 2  Noriko  [('Creamy Toffee-R +$8.50', 'https://cdn.shopi...
# 3  Noriko  [('Light Chocolate', 'https://cdn.shopify.com/...
# 4  Noriko  [('Toasted Brown', 'https://cdn.shopify.com/s/...
#
#                                           main_image  \
# 0  http://cdn.shopify.com/s/files/1/1025/3631/pro...
# 1  http://cdn.shopify.com/s/files/1/1025/3631/pro...
# 2  http://cdn.shopify.com/s/files/1/1025/3631/pro...
# 3  http://cdn.shopify.com/s/files/1/1025/3631/pro...
# 4  http://cdn.shopify.com/s/files/1/1025/3631/pro...
#
#                                                price  \
# 0  [20400, 19125, 19125, 19125, 19125, 19125, 191...
# 1  [17340, 17340, 17340, 17340, 17340, 17340, 173...
# 2  [16830, 15980, 15980, 15980, 15980, 15980, 159...
# 3  [17680, 17680, 17680, 17680, 17680, 17680, 176...
# ...

# %%
all_brands = data.brand.unique()
all_brands
# Out:
# array(['Noriko', 'Jon Renau', 'Amore', 'Raquel Welch', 'Rene of Paris',
#        'TressAllure', 'Hairdo by Hair U Wear', 'Revlon', 'Estetica',
#        'Gabor', 'Belle Tress', 'Ellen Wille', 'Envy', 'Tony of Beverly',
#        'Jon Renau Addition', 'Mane Attraction',
#        'Ellen Wille Hair Society', 'Tony of Beverly Addition', 'HIM',
#        'Incognito', 'Henry Margu', 'Orchid', 'Revlon Sale', 'EasiHair',
#        'Jon Renau Sale', 'Noriko Sale', 'Jon Renau Illusions',
#        'EasiHair Sale', 'Gabor Sale', 'Syntress', 'Jon Renau Evolution',
#        'Amore Sale', 'Raquel Welch Sale', 'Rene of Paris Sale',
#        'Ellen Wille Sale', 'Tony of Beverly Sale', 'Envy Sale',
#        'TressAllure Sale', 'Belle Tress Sale', 'Aspen Sale',
#        'Hairdo by Hair U Wear Sale', 'Estetica Sale', 'Henry Margu Sale',
#        'Aspen Imagination Sale', 'Syntress Sale', 'HIM Sale',
#        'Mane Attraction Sale', 'HIM SALE'], dtype=object)

# %%
all_brands[-1].split(" SALE")
# Out:
# ['HIM SALE']
